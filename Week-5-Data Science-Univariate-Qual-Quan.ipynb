# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("quality.csv")

# %%
dataset
# Out:
#      MemberID  InpatientDays  ERVisits  OfficeVisits  Narcotics  \
# 0           1              0         0            18          1
# 1           2              1         1             6          1
# 2           3              0         0             5          3
# 3           4              0         1            19          0
# 4           5              8         2            19          3
# ..        ...            ...       ...           ...        ...
# 126       127              1         1             5          3
# 127       128              1         0             3          2
# 128       129             15        11             5          9
# 129       130              0         2            14          1
# 130       131             30         1            22          3
#
#      DaysSinceLastERVisit  Pain  TotalVisits  ProviderCount  MedicalClaims  \
# 0              731.000000    10           18             21             93
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MemberID              131 non-null    int64
#  1   InpatientDays         131 non-null    int64
#  2   ERVisits              131 non-null    int64
#  3   OfficeVisits          131 non-null    int64
#  4   Narcotics             131 non-null    int64
#  5   DaysSinceLastERVisit  131 non-null    float64
#  6   Pain                  131 non-null    int64
#  7   TotalVisits           131 non-null    int64
#  8   ProviderCount         131 non-null    int64
#  9   MedicalClaims         131 non-null    int64
#  10  ClaimLines            131 non-null    int64
#  11  StartedOnCombination  131 non-null    bool
#  12  AcuteDrugGapSmall     131 non-null    int64
#  13  PoorCare              131 non-null    int64
# dtypes: bool(1), float64(1), int64(12)
# memory usage: 13.6 KB

# %%
#Quan=["InpatientDays", "ERVisits", "OfficeVisits", "Narcotics",  "DaysSinceLastERVisit", "Pain", "TotalVisits", "ProviderCount", "MedicalClaims", "MedicalClaims","ClaimLines", "AcuteDrugGapSmall"]

# %%
#Quan

# %%
#Qual=["MemberID","PoorCare","StartedOnCombination"]

# %%
#Qual

# %%
dataset.columns
# Out:
# Index(['MemberID', 'InpatientDays', 'ERVisits', 'OfficeVisits', 'Narcotics',
#        'DaysSinceLastERVisit', 'Pain', 'TotalVisits', 'ProviderCount',
#        'MedicalClaims', 'ClaimLines', 'StartedOnCombination',
#        'AcuteDrugGapSmall', 'PoorCare'],
#       dtype='object')

# %%
dir(dataset)
# Out:
# ['AcuteDrugGapSmall',
#  'ClaimLines',
#  'DaysSinceLastERVisit',
#  'ERVisits',
#  'InpatientDays',
#  'MedicalClaims',
#  'MemberID',
#  'Narcotics',
#  'OfficeVisits',
#  'Pain',
#  'PoorCare',
#  'ProviderCount',
#  'StartedOnCombination',
#  'T',
#  'TotalVisits',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
# ...

# %%
dataset.dtypes
# Out:
# MemberID                  int64
# InpatientDays             int64
# ERVisits                  int64
# OfficeVisits              int64
# Narcotics                 int64
# DaysSinceLastERVisit    float64
# Pain                      int64
# TotalVisits               int64
# ProviderCount             int64
# MedicalClaims             int64
# ClaimLines                int64
# StartedOnCombination       bool
# AcuteDrugGapSmall         int64
# PoorCare                  int64
# dtype: object

# %%
dataset["StartedOnCombination"].dtype
# Out:
# dtype('bool')

# %%
dataset["InpatientDays"].dtype
# Out:
# dtype('int64')

# %%
for ColumnName in dataset.columns:
    print(ColumnName)
# Out:
# MemberID
# InpatientDays
# ERVisits
# OfficeVisits
# Narcotics
# DaysSinceLastERVisit
# Pain
# TotalVisits
# ProviderCount
# MedicalClaims
# ClaimLines
# StartedOnCombination
# AcuteDrugGapSmall
# PoorCare

# %%
"""if (dataset["StartedOnCombination"].dtype==bool):
    print("qual")
else:
    print("quan")"""
# Out:
# 'if (dataset["StartedOnCombination"].dtype==bool):\n    print("qual")\nelse:\n    print("quan")'

# %%
quan=[]
qual=[]
for ColumnName in dataset.columns:
    print(ColumnName)
    if (dataset[ColumnName].dtype==bool):
        qual.append(ColumnName)
    elif (dataset[ColumnName].nunique()== 2):
        qual.append(ColumnName)
    elif (dataset[ColumnName].nunique()==len(dataset)):
        qual.append(ColumnName)
    else:
        quan.append(ColumnName)
# Out:
# MemberID
# InpatientDays
# ERVisits
# OfficeVisits
# Narcotics
# DaysSinceLastERVisit
# Pain
# TotalVisits
# ProviderCount
# MedicalClaims
# ClaimLines
# StartedOnCombination
# AcuteDrugGapSmall
# PoorCare

# %%
quan
# Out:
# ['InpatientDays',
#  'ERVisits',
#  'OfficeVisits',
#  'Narcotics',
#  'DaysSinceLastERVisit',
#  'Pain',
#  'TotalVisits',
#  'ProviderCount',
#  'MedicalClaims',
#  'ClaimLines',
#  'AcuteDrugGapSmall']

# %%
qual
# Out:
# ['MemberID', 'StartedOnCombination', 'PoorCare']

# %%
def QuanQual(dataset):
    quan=[]
    qual=[]
    for ColumnName in dataset.columns:
        print(ColumnName)
        if (dataset[ColumnName].dtype==bool):
            qual.append(ColumnName)
        elif (dataset[ColumnName].nunique()== 2):
            qual.append(ColumnName)
        elif (dataset[ColumnName].nunique()==len(dataset)):
            qual.append(ColumnName)
        else:
            quan.append(ColumnName)

    return quan,qual

# %%
QuanQual(dataset)
# Out:
# MemberID
# InpatientDays
# ERVisits
# OfficeVisits
# Narcotics
# DaysSinceLastERVisit
# Pain
# TotalVisits
# ProviderCount
# MedicalClaims
# ClaimLines
# StartedOnCombination
# AcuteDrugGapSmall
# PoorCare
# (['InpatientDays',
#   'ERVisits',
#   'OfficeVisits',
#   'Narcotics',
#   'DaysSinceLastERVisit',
#   'Pain',
#   'TotalVisits',
#   'ProviderCount',
#   'MedicalClaims',
#   'ClaimLines',
#   'AcuteDrugGapSmall'],
#  ['MemberID', 'StartedOnCombination', 'PoorCare'])

# %%
quan=QuanQual(dataset)
# Out:
# MemberID
# InpatientDays
# ERVisits
# OfficeVisits
# Narcotics
# DaysSinceLastERVisit
# Pain
# TotalVisits
# ProviderCount
# MedicalClaims
# ClaimLines
# StartedOnCombination
# AcuteDrugGapSmall
# PoorCare

# %%
qual=QuanQual(dataset)
# Out:
# MemberID
# InpatientDays
# ERVisits
# OfficeVisits
# Narcotics
# DaysSinceLastERVisit
# Pain
# TotalVisits
# ProviderCount
# MedicalClaims
# ClaimLines
# StartedOnCombination
# AcuteDrugGapSmall
# PoorCare
